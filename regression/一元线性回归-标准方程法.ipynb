# %%
# 推导公式见 `一元一次标准方程法.md`
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data = np.genfromtxt('./regression/data.csv', delimiter=',')
print(data[0])
# Out:
# [0.74122909 1.51320286]

# %%
# 绘制散点图
plt.scatter(data[:,0], data[:,1], color='#ef4136')
plt.figure(figsize=(9, 16))
plt.show()
